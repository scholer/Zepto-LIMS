# %%
# %matplotlib --list
# Out:
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']

# %%
# %matplotlib notebook
# %matplotlib [-l] [gui]
# %matplotlib --list
# Available matplotlib backends: ['tk', 'gtk', 'gtk3', 'wx', 'qt4', 'qt5', 'qt', 'osx', 'nbagg', 'notebook', 'agg', 'svg', 'pdf', 'ps', 'inline', 'ipympl', 'widget']
# notebook gives you interactive plots,
# inline gives static images.
# widget (formerly ipympl) is an alternative to notebook. 
# https://ipython.readthedocs.io/en/stable/interactive/magics.html#magic-matplotlib
# https://medium.com/@1522933668924/using-matplotlib-in-jupyter-notebooks-comparing-methods-and-some-tips-python-c38e85b40ba1
# Alternatively, just call IPython.display.display(obj) on the objects you would like to display.

# %%
import os
import sys
import pathlib
import matplotlib
from matplotlib import pyplot
from IPython.display import display
print("Notebook path:", pathlib.Path(".").absolute())
# Out:
# Notebook path: C:\Users\au206270\Dev\zepto-lims\notebooks

# %%
# Make sure you have pip-installed using e.g. `pip install -e .`
import zepto_lims
from zepto_lims.scanners import boxscanner
from zepto_lims.utils.image import imread


PROJECT_ROOT_DIR = pathlib.Path(zepto_lims.__file__).parent.parent 
TEST_DATA_DIR = PROJECT_ROOT_DIR / "tests" / "testdata"

datamatrix_1x_image = imread(TEST_DATA_DIR / 'images' / 'datamatrix_x1_02_25pct-q90.jpg')
datamatrix_4x_image = imread(TEST_DATA_DIR / 'images' / 'datamatrix_x4_50pct-90.jpg')

# %%
pyplot.imshow(datamatrix_4x_image)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
grid_params = (10, -1, 20, -10, (4, 1))  # rows, cols
im_grid = boxscanner.segment_image_to_grid(datamatrix_4x_image, grid_params=grid_params)
pyplot.imshow(im_grid[1][0])
# Out:
# image.shape (940, 179)
# im_cropped.shape: (929, 149)
# nrows, ncols: 4 1
# image height, width: 929 149
# segment shapes: [[(232, 149)], [(232, 149)], [(232, 149)], [(233, 149)]]

# %%
#  boxscanner.scan_lid_barcode(im_grid[1][0])

fig, axes = pyplot.subplots(4, 1)

for row in im_grid:
    for im in row:
        pyplot.imshow(im)
        print(boxscanner.scan_lid_barcode(im))
# Out:
# 190728 RS123d2 S2Descr
# None
# 190728 RS123d2 S2Descr
# 20190729 RS123d1 Sample Test description
